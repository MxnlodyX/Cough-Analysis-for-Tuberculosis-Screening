# %% [markdown]
# # **Fine-tuning Model with CODA From South East Asia (SEA) + Siriraj for TB Classification**

# %% [markdown]
# ## **Import Libraries**

# %%
import os
import pandas as pd
import numpy as np
import gc
from pathlib import Path
from typing import List, Dict
import re
import copy
from tqdm.auto import tqdm
import random

# ==== Torch ====
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader

# ==== Scikit Learn ====
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from sklearn.metrics import (
    average_precision_score,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    auc,
    f1_score, 
    accuracy_score
)

# ==== Visulization ====
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.cm as cm
import seaborn as sns

# ==== Chroma Vector Database ====
import chromadb
from chromadb.config import Settings

# %% [markdown]
# ## **Project Setup**

# %%
# ==== Check Device ==== 
if torch.cuda.is_available():
    DEVICE = torch.device("cuda")
    print(torch.version.cuda)
    print(f"✅ Using CUDA device: {torch.cuda.get_device_name(0)}")
else:
    DEVICE = torch.device("cpu")
    print("⚠️ CUDA not available. Using CPU.")
print(f"Device: {DEVICE}")
# Out:
# 12.8
# ✅ Using CUDA device: NVIDIA GeForce RTX 5060 Laptop GPU
# Device: cuda

# %% [markdown]
# ## **Configuration Parameters**

# %%
# ==== Path Configurations ====
DB_PATH:str = "../../data/chroma_db"

# ==== Vector Database ====
CODA_DB: str = "coda_vector_db"
SI_DB: str = "old_siriraj_vector_db"
CHROMA_GET_BATCH_SIZE: str = 4096

# ==== Data Splitting ====
n_folds: int = 5
val_size: float = 0.25

# ==== Seed Setting ====
seed: int = 42

# ==== MLP Classification Architecture ====
INPUT_SIZE: int = 512
HIDDEN_SIZE: int = 256 
OUTPUT_SIZE: int = 1
HIDDEN_DIMS: List[int] = [256, 128, 64]
DROPOUT: float = 0.5

# ==== Early Stopping ====
PATIENCE: int = 10
MODE: str = "min"
MONITOR: str = "val_loss"
DELTA: float = 0.001

# ==== Training Loop =========================================

# - Pre-train (CODA) — large dataset, more epochs
PT_EPOCHS       = 30
PT_LR           = 3e-4
PT_BATCH_SIZE   = 16     # large batch for 700k samples
PT_PATIENCE     = 10

# - Fine-tune (SI) — small dataset, fewer epochs, lower LR
FT_EPOCHS       = 20
FT_LR           = 1e-5    # 30x lower than pre-train LR
FT_BATCH_SIZE   = 8       # small batch for 512 samples
FT_PATIENCE     = 10

# ============================================================

# ==== Optimizer ====
OPTIMIZER: str = "adam"

# ==== Loss Function ====
LOSS_FUNCTION: str = "focal_loss"

print("✅ Configuration loaded.")
# Out:
# ✅ Configuration loaded.

# %% [markdown]
# ### Locked Random Seed

# %%
def set_seed(seed: int = 42) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    # Environment
    os.environ['PYTHONHASHSEED'] = str(seed)
    print(f"✅ Random seed set to {seed}")

set_seed(seed)
print("✅ All random seeds locked for reproducibility!")
# Out:
# ✅ Random seed set to 42
# ✅ All random seeds locked for reproducibility!

# %% [markdown]
# ## **Data Preparation**

# %% [markdown]
# ### Fetch and Build Dataframe

# %%
def fetch_all_from_chroma(collection, batch_size: int = 32) -> dict:
    """Fetch all records in batches to avoid SQLite variable limit."""
    total          = collection.count()
    all_embeddings = []
    all_metadatas  = []
    all_ids        = []

    for offset in tqdm(range(0, total, batch_size), desc=f"Fetching {collection.name}"):
        batch = collection.get(
            include = ["embeddings", "metadatas"],
            limit   = batch_size,
            offset  = offset,
        )
        all_embeddings.extend(batch["embeddings"])
        all_metadatas.extend(batch["metadatas"])
        all_ids.extend(batch["ids"])

    return {
        "embeddings" : np.array(all_embeddings, dtype=np.float32),
        "metadatas"  : all_metadatas,
        "ids"        : all_ids,
    }

# %%
chroma_client = chromadb.PersistentClient(path=DB_PATH)

coda_collection = chroma_client.get_collection(name=CODA_DB)
si_collection = chroma_client.get_collection(name=SI_DB)

# %% [markdown]
# ### Build Dataframe from Database

# %%
def build_df_from_db(collection, batch_size: int = 40) -> pd.DataFrame:
    results    = fetch_all_from_chroma(collection, batch_size=batch_size)
    embeddings = results["embeddings"]
    metadatas  = results["metadatas"]
    ids        = results["ids"]

    emb_cols = [f"emb_{i}" for i in range(embeddings.shape[1])]
    emb_df   = pd.DataFrame(embeddings, columns=emb_cols)

    meta_df       = pd.DataFrame(metadatas)
    meta_df["id"] = ids

    # ==== Base columns always present ====
    base_cols = ["id", "file_name", "label", "category"]

    # ==== Optional columns — fill with 'unknown' if missing ====
    if "country" not in meta_df.columns:
        meta_df["country"] = "TH"
    if "participant" not in meta_df.columns:
        meta_df["participant"] = None

    df = pd.concat(
        [meta_df[base_cols + ["country", "participant"]], emb_df],
        axis=1
    )
    df["label"] = df["label"].astype(int)
    return df

# %% [markdown]
# #### Siriraj

# %%
print("📦 Fetching SI dataset...")
df_si = build_df_from_db(si_collection)

print(f"\n✅ SI Dataset")
print(f"   Shape    : {df_si.shape}")
print(f"   Non-TB   : {(df_si['label'] == 0).sum():,}")
print(f"   TB       : {(df_si['label'] == 1).sum():,}")
df_si.iloc[:, :12].head()
# Out:
# 📦 Fetching SI dataset...
# Fetching old_siriraj_vector_db:   0%|          | 0/13 [00:00<?, ?it/s]
# ✅ SI Dataset
#    Shape    : (512, 518)
#    Non-TB   : 325
#    TB       : 187
#         id      file_name  label category country participant     emb_0  \
# 0  audio_0  001_02-01.wav      0   Non-TB      TH        None -1.044960
# 1  audio_1  001_02-02.wav      0   Non-TB      TH        None -1.765482
# 2  audio_2  001_02-03.wav      0   Non-TB      TH        None -1.755122
# 3  audio_3  001_02-04.wav      0   Non-TB      TH        None -1.185073
# 4  audio_4  001_02-05.wav      0   Non-TB      TH        None -1.337682
#
#       emb_1     emb_2     emb_3     emb_4     emb_5
# 0 -0.994985  1.841995 -8.510449  3.532761 -2.059614
# 1  0.497430 -0.309609 -5.022780  1.755003 -3.526640
# 2 -0.227196 -0.900034 -4.662507  1.684681 -2.988435
# 3 -0.686719 -2.149752 -4.081336  2.263366 -3.325819
# 4 -1.053523 -1.396001 -4.157047  1.785936 -3.015491

# %% [markdown]
# #### CODA (SEA)

# %%
df_coda = build_df_from_db(coda_collection, batch_size=4096)

df_coda_sea = df_coda[df_coda["country"].isin(["PH", "VN"])].reset_index(drop=True)

print(f"\n✅ CODA SEA (Southeast Asia) — Test Set")
print(f"   Shape    : {df_coda_sea.shape}")
print(f"   Non-TB   : {(df_coda_sea['label'] == 0).sum():,}")
print(f"   TB       : {(df_coda_sea['label'] == 1).sum():,}")

df_coda_sea.head()
# Out:
# Fetching coda_vector_db:   0%|          | 0/175 [00:00<?, ?it/s]
# ✅ CODA SEA (Southeast Asia) — Test Set
#    Shape    : (172292, 518)
#    Non-TB   : 112,220
#    TB       : 60,072
#         id                      file_name  label category country  \
# 0  coda_10  1646915237787-recording-1.wav      0   Non-TB      PH
# 1  coda_11  1634075609319-recording-1.wav      1       TB      PH
# 2  coda_21  1647113046046-recording-1.wav      0   Non-TB      PH
# 3  coda_22  1633463364900-recording-1.wav      0   Non-TB      PH
# 4  coda_24  1632386423429-recording-1.wav      1       TB      PH
#
#     participant     emb_0     emb_1     emb_2      emb_3  ...    emb_502  \
# 0  CODA_TB_1100 -1.534153  0.649789 -0.003221  -6.905223  ...   2.598986
# 1  CODA_TB_0684 -0.772977  2.642561 -1.983489  -5.633994  ...   3.907030
# 2  CODA_TB_1100 -2.115136 -3.875006  3.535236 -10.057935  ...  12.860758
# 3  CODA_TB_0458 -2.291505  1.790418  3.470539  -7.849823  ...   5.090691
# 4  CODA_TB_0569 -3.061549  1.241976  1.818423  -7.751103  ...   2.369550
#
#     emb_503   emb_504   emb_505   emb_506   emb_507   emb_508   emb_509  \
# 0  4.096417  6.332577  4.090514  6.863942  1.210778  8.212391  6.211445
# 1  3.184196  5.920643  5.359656  7.707446  0.831639  8.343218  8.268652
# 2  1.466960 -0.655672  4.751556  8.934015  6.575618  0.758573 -3.800219
# 3  1.687278  5.312859  4.075458  8.038671  5.991591  8.640991  5.294898
# 4  2.258004  3.660888  2.600485  8.515150  3.328403  6.089859  7.844516
#
#     emb_510   emb_511
# 0  2.371614  3.295353
# 1  3.159344  5.782824
# 2  5.462012  2.823737
# 3  6.224087  4.210166
# 4  4.236391  2.065995
#
# [5 rows x 518 columns]

# %% [markdown]
# ### Build Subject Table

# %%
def extract_subject_id(filename):
    """Extracts the subject ID (first 3 digits) from the filename."""
    match = re.match(r"^(\d{3})_", filename)
    if match:
        return match.group(1)
    else:
        # Fallback if pattern doesn't match perfectly
        return filename.split('_')[0]

# %% [markdown]
# #### Siriraj

# %%
# Add 'subject_id' column
df_si['subject_id'] = df_si['file_name'].apply(extract_subject_id)

print(f"Total samples: {len(df_si)}")
print(f"Unique subjects: {df_si['subject_id'].nunique()}")
# Out:
# Total samples: 512
# Unique subjects: 15

# %% [markdown]
# #### CODA (SEA)

# %%
# Add 'subject_id' column
df_coda_sea['subject_id'] = df_coda_sea['participant']

print(f"Total samples: {len(df_coda_sea)}")
print(f"Unique participants: {df_coda_sea['subject_id'].nunique():,}")
# Out:
# Total samples: 172292
# Unique participants: 239

# %%
def build_subject_table(df):
    """Creates a DataFrame with one row per subject and their majority label."""
    # Group by subject_id
    # Get the most frequent label (mode)
    subject_df = (
        df.groupby("subject_id")["label"]
        .agg(lambda x: x.mode()[0])
        .reset_index()
        .rename(columns={"label": "subject_label"})
    )
    return subject_df

# %% [markdown]
# #### Siriraj

# %%
subject_table_si = build_subject_table(df_si)

X_si_subj = subject_table_si["subject_id"].values
y_si_subj = subject_table_si["subject_label"].values

print(subject_table_si)
print("="*80)
print(f"\nTotal Unique Subjects: {len(X_si_subj)}")
# Out:
#    subject_id  subject_label
# 0         001              0
# 1         002              0
# 2         003              0
# 3         004              0
# 4         005              0
# 5         006              1
# 6         007              0
# 7         008              1
# 8         009              1
# 9         011              1
# 10        012              1
# 11        013              0
# 12        014              0
# 13        015              1
# 14        016              1
# ================================================================================
#
# Total Unique Subjects: 15

# %% [markdown]
# #### CODA

# %%
subject_table_coda_sea = build_subject_table(df_coda_sea)

X_coda_sea_in_subj = subject_table_coda_sea["subject_id"].values
y_coda_sea_in_subj = subject_table_coda_sea["subject_label"].values

print(subject_table_coda_sea.head())
print("="*80)
print(f"\nTotal Unique Subjects: {len(X_coda_sea_in_subj)}")
# Out:
#      subject_id  subject_label
# 0  CODA_TB_0003              0
# 1  CODA_TB_0009              0
# 2  CODA_TB_0013              1
# 3  CODA_TB_0015              0
# 4  CODA_TB_0020              0
# ================================================================================
#
# Total Unique Subjects: 239

# %% [markdown]
# ### Helper Function

# %%
def filter_by_subjects(df: pd.DataFrame, subject_ids) -> pd.DataFrame:
    return df[df["subject_id"].isin(set(subject_ids))].reset_index(drop=True)


def print_detailed_stats(df: pd.DataFrame, subj_ids, split_name: str, total_n: int):
    subset         = df[df["subject_id"].isin(subj_ids)]
    tb_df          = subset[subset["label"] == 1]
    nontb_df       = subset[subset["label"] == 0]
    tb_subjs       = sorted(tb_df["subject_id"].unique().tolist())
    nontb_subjs    = sorted(nontb_df["subject_id"].unique().tolist())
    ratio          = len(subj_ids) / total_n

    print(f"  {split_name.upper():5s} SET : {len(subj_ids):>2} subjects ({ratio:.2%})")
    print(f"   ├─ TB    (1) : {len(tb_df):>4} segments | IDs: {', '.join(tb_subjs)}")
    print(f"   └─ NonTB (0) : {len(nontb_df):>4} segments | IDs: {', '.join(nontb_subjs)}")

# %% [markdown]
# ## **Stratified K Fold for Splitting Data**

# %%
def build_cv_folds(
    df_si       : pd.DataFrame,   # SI         — Fine tuning(Train/Val) and Test source
    df_coda     : pd.DataFrame,   # CODA India — Train/Val source
    n_folds     : int   = 5,
    val_size    : float = 0.25,
    random_seed : int   = 42,
) -> dict:

    # ==== CODA subject table (for train/val splits) ====
    subject_table_coda = build_subject_table(df_coda)
    X_coda_subj  = subject_table_coda["subject_id"].values
    y_coda_subj  = subject_table_coda["subject_label"].values
    n_coda_total = len(X_coda_subj)

    # ==== SI subject table (for rotating test splits) ====
    subject_table_si = build_subject_table(df_si)
    X_si_subj  = subject_table_si["subject_id"].values
    y_si_subj  = subject_table_si["subject_label"].values
    n_si_total = len(X_si_subj)

    print(f"\n{'='*80}")
    print(f"  Building {n_folds}-fold combined splits  (CODA for Train/Val · SI test)")
    print(f"{'='*80}")
    print(f"  CODA subjects : {n_coda_total}  | clips: {len(df_coda):,}")
    print(f"  SI subjects   : {n_si_total}     | clips: {len(df_si):,}")

    # ==== SKF on CODA subjects (train/val) ====
    coda_skf    = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=random_seed)

    # ==== SKF on SI subjects (rotating test) ====
    si_skf      = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=random_seed)

    all_folds   = []
    coda_splits = list(coda_skf.split(X_coda_subj, y_coda_subj))
    si_splits   = list(si_skf.split(X_si_subj, y_si_subj))

    for fold_idx, (
        (coda_trainval_idx, _),   # ← outer fold gives us 80% CODA for train+val
        (si_ft_idx,     si_test_idx)         # ← outer fold gives us 20% SI for test
    ) in enumerate(zip(coda_splits, si_splits), start=1):

        # ===========================================================
        # CODA: use the 60% trainval portion → split into train/val 
        # ===========================================================
        coda_tv_subj = X_coda_subj[coda_trainval_idx]
        y_tv         = y_coda_subj[coda_trainval_idx]

        inner = StratifiedShuffleSplit(
            n_splits=1,
            test_size=val_size,              # 0.25 of 80% = 20% overall
            random_state=random_seed + fold_idx   # ← different seed per fold
        )
        inner_train_idx, inner_val_idx = next(inner.split(coda_tv_subj, y_tv))

        train_subj = coda_tv_subj[inner_train_idx]   # ~60% of all CODA subjects
        val_subj   = coda_tv_subj[inner_val_idx]     # ~20% of all CODA subjects

        # ======================================================================
        # SI: use the 80% Fine-tuning Train(60%)/Val(20%) and 20% test portion 
        # ======================================================================
        si_ft_subj = X_si_subj[si_ft_idx]
        y_ft_subj  = y_si_subj[si_ft_idx]    

        ft_inner = StratifiedShuffleSplit(
            n_splits=1,
            test_size=val_size,              # 0.25 of 80% = 20% overall
            random_state=random_seed + fold_idx   # ← different seed per fold
        )

        ft_train_idx, ft_val_idx = next(ft_inner.split(si_ft_subj, y_ft_subj))
        ft_train_subj = si_ft_subj[ft_train_idx]   # ~60% of SI subjects for fine-tuning train
        ft_val_subj   = si_ft_subj[ft_val_idx]     # ~20% of SI subjects for fine-tuning

        si_test_subj = X_si_subj[si_test_idx]        # ~20% of SI subjects

        # ==== Leakage checks ====
        assert set(train_subj).isdisjoint(set(val_subj)),      f"Fold {fold_idx}: CODA train/val overlap!"
        # Note: CODA and SI have completely different subject IDs so cross-dataset
        # leakage is impossible, but we check anyway for safety
        assert set(train_subj).isdisjoint(set(si_test_subj)),  f"Fold {fold_idx}: train/SI-test overlap!"
        assert set(val_subj).isdisjoint(set(si_test_subj)),    f"Fold {fold_idx}: val/SI-test overlap!"
        assert set(ft_train_subj).isdisjoint(set(si_test_subj)), f"Fold {fold_idx}: SI fine-tune train/SI-test overlap!"
        assert set(ft_val_subj).isdisjoint(set(si_test_subj)),   f"Fold {fold_idx}: SI fine-tune val/SI-test overlap!"

        # ==== Filter DataFrames ====
        train_df = filter_by_subjects(df_coda, train_subj)
        val_df   = filter_by_subjects(df_coda, val_subj)
        test_df  = filter_by_subjects(df_si,   si_test_subj)
        ft_train_df = filter_by_subjects(df_si, ft_train_subj)
        ft_val_df   = filter_by_subjects(df_si, ft_val_subj)

        # ==== Stats ====
        tb_train    = (train_df["label"] == 1).sum()
        nontb_train = (train_df["label"] == 0).sum()
        tb_val      = (val_df["label"] == 1).sum()
        nontb_val   = (val_df["label"] == 0).sum()
        tb_ft_train = (ft_train_df["label"] == 1).sum()
        nontb_ft_train = (ft_train_df["label"] == 0).sum()
        tb_ft_val   = (ft_val_df["label"] == 1).sum()
        nontb_ft_val   = (ft_val_df["label"] == 0).sum()
        tb_test     = (test_df["label"] == 1).sum()
        nontb_test  = (test_df["label"] == 0).sum()

        # Ratios based on CLIP counts (not subject counts) to match expected output
        ratio_train = len(train_df) / len(df_coda)
        ratio_val   = len(val_df)   / len(df_coda)
        ratio_test  = len(test_df)  / len(df_si)
        ratio_ft_train = len(ft_train_df) / len(df_si)
        ratio_ft_val   = len(ft_val_df)   / len(df_si)

        print(f"\n── Fold {fold_idx} ──")
        print(f"  Train(CODA)         : {len(train_df):>7,} segments ({ratio_train:.1%})"
              f" | TB: {tb_train:>7,} segments | NonTB: {nontb_train:>7,} segments")
        print(f"  Val(CODA)           : {len(val_df):>7,} segments ({ratio_val:.1%})"
              f" | TB: {tb_val:>7,} segments | NonTB: {nontb_val:>7,} segments")
        print(f"  Fine-tune Train(SI) : {len(ft_train_df):>7,} segments ({ratio_ft_train:.1%})"
              f" | TB: {tb_ft_train:>7,} segments | NonTB: {nontb_ft_train:>7,} segments")
        print(f"  Fine-tune Val(SI)   : {len(ft_val_df):>7,} segments ({ratio_ft_val:.1%})"
              f" | TB: {tb_ft_val:>7,} segments | NonTB: {nontb_ft_val:>7,} segments")
        print(f"  Test(SI)            : {len(test_df):>7,} segments ({ratio_test:.1%})"
              f" | TB: {tb_test:>7,} segments | NonTB: {nontb_test:>7,} segments")

        all_folds.append({
            "fold"       : fold_idx,
            "seed"       : random_seed + fold_idx,
            "train"      : train_df,
            "val"        : val_df,
            "ft_train"   : ft_train_df,
            "ft_val"     : ft_val_df,
            "test"       : test_df,
            "train_subj" : sorted(train_subj.tolist()),
            "val_subj"   : sorted(val_subj.tolist()),
            "test_subj"  : sorted(si_test_subj.tolist()),
        })

    print(f"\n{'='*100}")
    print(f"  ✅ NO SUBJECT LEAKAGE  (CODA train/val disjoint; SI Fine-tune and test is independent)")
    print(f"{'='*100}\n")

    return {
        "subject_table_coda" : subject_table_coda,
        "subject_table_si"   : subject_table_si,
        "folds"              : all_folds,
    }

# %%
splits = build_cv_folds(
    df_si, 
    df_coda_sea, 
    n_folds=n_folds, 
    val_size=val_size, 
    random_seed=seed
)
# Out:
# ================================================================================
#   Building 5-fold combined splits  (CODA for Train/Val · SI test)
# ================================================================================
#   CODA subjects : 239  | clips: 172,292
#   SI subjects   : 15     | clips: 512
#
# ── Fold 1 ──
#   Train(CODA)         : 103,977 segments (60.3%) | TB:  31,154 segments | NonTB:  72,823 segments
#   Val(CODA)           :  31,343 segments (18.2%) | TB:  11,340 segments | NonTB:  20,003 segments
#   Fine-tune Train(SI) :     258 segments (50.4%) | TB:     125 segments | NonTB:     133 segments
#   Fine-tune Val(SI)   :     170 segments (33.2%) | TB:      20 segments | NonTB:     150 segments
#   Test(SI)            :      84 segments (16.4%) | TB:      42 segments | NonTB:      42 segments
#
# ── Fold 2 ──
#   Train(CODA)         : 114,815 segments (66.6%) | TB:  47,116 segments | NonTB:  67,699 segments
#   Val(CODA)           :  29,260 segments (17.0%) | TB:   7,676 segments | NonTB:  21,584 segments
#   Fine-tune Train(SI) :     252 segments (49.2%) | TB:     149 segments | NonTB:     103 segments
#   Fine-tune Val(SI)   :     151 segments (29.5%) | TB:       1 segments | NonTB:     150 segments
#   Test(SI)            :     109 segments (21.3%) | TB:      37 segments | NonTB:      72 segments
#
# ── Fold 3 ──
#   Train(CODA)         :  97,072 segments (56.3%) | TB:  26,633 segments | NonTB:  70,439 segments
#   Val(CODA)           :  31,580 segments (18.3%) | TB:  13,405 segments | NonTB:  18,175 segments
#   Fine-tune Train(SI) :     302 segments (59.0%) | TB:     129 segments | NonTB:     173 segments
#   Fine-tune Val(SI)   :      70 segments (13.7%) | TB:      38 segments | NonTB:      32 segments
#   Test(SI)            :     140 segments (27.3%) | TB:      20 segments | NonTB:     120 segments
#
# ── Fold 4 ──
#   Train(CODA)         : 107,575 segments (62.4%) | TB:  44,607 segments | NonTB:  62,968 segments
#   Val(CODA)           :  32,938 segments (19.1%) | TB:   7,682 segments | NonTB:  25,256 segments
#   Fine-tune Train(SI) :     386 segments (75.4%) | TB:     162 segments | NonTB:     224 segments
#   Fine-tune Val(SI)   :      71 segments (13.9%) | TB:      20 segments | NonTB:      51 segments
#   Test(SI)            :      55 segments (10.7%) | TB:       5 segments | NonTB:      50 segments
#
# ── Fold 5 ──
#   Train(CODA)         : 103,501 segments (60.1%) | TB:  32,306 segments | NonTB:  71,195 segments
#   Val(CODA)           :  37,107 segments (21.5%) | TB:  18,369 segments | NonTB:  18,738 segments
#   Fine-tune Train(SI) :     278 segments (54.3%) | TB:      84 segments | NonTB:     194 segments
#   Fine-tune Val(SI)   :     110 segments (21.5%) | TB:      20 segments | NonTB:      90 segments
#   Test(SI)            :     124 segments (24.2%) | TB:      83 segments | NonTB:      41 segments
#
# ====================================================================================================
#   ✅ NO SUBJECT LEAKAGE  (CODA train/val disjoint; SI Fine-tune and test is independent)
# ====================================================================================================

# %% [markdown]
# ## **Embedding Extraction & Fold Data Preparation**

# %%
EMB_COLS = [c for c in df_si.columns if c.startswith("emb_")]

def get_fold_XY(fold: dict):
    """Extract all 5 splits as numpy arrays from a fold dict."""
    def to_XY(df):
        X = df[EMB_COLS].values.astype(np.float32)
        y = df["label"].values.astype(int)
        return X, y

    X_train,    y_train    = to_XY(fold["train"])
    X_val,      y_val      = to_XY(fold["val"])
    X_ft_train, y_ft_train = to_XY(fold["ft_train"])
    X_ft_val,   y_ft_val   = to_XY(fold["ft_val"])
    X_test,     y_test     = to_XY(fold["test"])

    return X_train, y_train, X_val, y_val, X_ft_train, y_ft_train, X_ft_val, y_ft_val, X_test, y_test


# Verify all folds
for fold in splits["folds"]:
    X_train, y_train, X_val, y_val, X_ft_train, y_ft_train, X_ft_val, y_ft_val, X_test, y_test = get_fold_XY(fold)
    print(f"Fold {fold['fold']} → "
          f"Train: {X_train.shape} | Val: {X_val.shape} | "
          f"FT-Train: {X_ft_train.shape} | FT-Val: {X_ft_val.shape} | "
          f"Test: {X_test.shape}")
# Out:
# Fold 1 → Train: (103977, 512) | Val: (31343, 512) | FT-Train: (258, 512) | FT-Val: (170, 512) | Test: (84, 512)
# Fold 2 → Train: (114815, 512) | Val: (29260, 512) | FT-Train: (252, 512) | FT-Val: (151, 512) | Test: (109, 512)
# Fold 3 → Train: (97072, 512) | Val: (31580, 512) | FT-Train: (302, 512) | FT-Val: (70, 512) | Test: (140, 512)
# Fold 4 → Train: (107575, 512) | Val: (32938, 512) | FT-Train: (386, 512) | FT-Val: (71, 512) | Test: (55, 512)
# Fold 5 → Train: (103501, 512) | Val: (37107, 512) | FT-Train: (278, 512) | FT-Val: (110, 512) | Test: (124, 512)

# %% [markdown]
# ## **MLP Classification**

# %%
class MLPModel(nn.Module):
    def __init__(self, input_dim: int, hidden_dims: List[int], dropout: float):
        super().__init__()

        self.input_dim    = input_dim
        self.hidden_dims  = hidden_dims
        self.dropout      = dropout

        layers   = []
        prev_dim = input_dim

        for hidden_dim in hidden_dims:
            layers.extend([
                nn.Linear(prev_dim, hidden_dim),
                nn.BatchNorm1d(hidden_dim),
                nn.ReLU(),
                nn.Dropout(dropout)
            ])
            prev_dim = hidden_dim
        
        # Output layer — single logit for binary classification
        layers.append(nn.Linear(prev_dim, 1))
        self.model = nn.Sequential(*layers)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.model(x)

    def get_model_info(self) -> Dict:
        """Return architecture summary."""
        total     = sum(p.numel() for p in self.parameters())
        trainable = sum(p.numel() for p in self.parameters() if p.requires_grad)
        return {
            "input_dim"       : self.input_dim,
            "hidden_dims"     : self.hidden_dims,
            "dropout"         : self.dropout,
            "total_params"    : total,
            "trainable_params": trainable,
        }

# %% [markdown]
# ## **Training MLP Classification Model**

# %% [markdown]
# ### Early Stopping

# %%
class EarlyStopping:
    def __init__(self, patience: int, mode: str , monitor: str, delta: float, verbose: bool = True):
        self.patience      = patience
        self.delta         = delta
        self.verbose       = verbose
        self.mode          = mode
        self.monitor       = monitor
        self.best_val_loss = float("inf")
        self.best_state    = None
        self.bad_epochs    = 0
        self.best_epoch    = 0
        self.early_stop    = False

    def __call__(self, val_loss: float, model: nn.Module, epoch: int) -> bool:
        improved = val_loss < (self.best_val_loss - self.delta)
        if improved:
            if self.verbose:
                print(f"  ✅ Val loss improved: {self.best_val_loss:.4f} → {val_loss:.4f}  (epoch {epoch+1})")
            self.best_val_loss = val_loss
            self.best_state    = copy.deepcopy(model.state_dict())
            self.bad_epochs    = 0
            self.best_epoch    = epoch
        else:
            self.bad_epochs += 1
            if self.verbose:
                print(f"  ❌ No improvement in val loss: {val_loss:.4f} (best: {self.best_val_loss:.4f})  [bad epochs: {self.bad_epochs}/{self.patience}]")
            if self.bad_epochs >= self.patience:
                if self.verbose:
                    print(f"  ⏰ Early stopping triggered after {self.bad_epochs} bad epochs.")
                self.early_stop = True
            return self.early_stop
    
    def restore_best_weights(self, model: nn.Module) -> None:
        """Load the best weights back into the model."""
        if self.best_state is not None:
            model.load_state_dict(self.best_state)
            if self.verbose:
                print(f"\n✅ Best weights restored from epoch {self.best_epoch+1} "
                      f"(val loss: {self.best_val_loss:.4f})")

# %% [markdown]
# ### Training Loop

# %%
all_fold_results = []
fold_data        = []

print("\n" + "="*80)
print(f"  Two-Phase Training: Pre-train (CODA) → Fine-tune (SI)")
print(f"  Device: {DEVICE}")
print("="*80)

for fold in splits["folds"]:
    fold_idx = fold["fold"]

    print(f"\n{'='*80}")
    print(f"  Fold {fold_idx} / {n_folds}")
    print(f"{'='*80}")

    X_train, y_train, X_val, y_val, \
    X_ft_train, y_ft_train, X_ft_val, y_ft_val, \
    X_test, y_test = get_fold_XY(fold)

    # ==== Tensors ====
    def to_tensor(X, y):
        return (torch.FloatTensor(X).to(DEVICE),
                torch.FloatTensor(y).unsqueeze(1).to(DEVICE))

    X_train_t,    y_train_t    = to_tensor(X_train,    y_train)
    X_val_t,      y_val_t      = to_tensor(X_val,      y_val)
    X_ft_train_t, y_ft_train_t = to_tensor(X_ft_train, y_ft_train)
    X_ft_val_t,   y_ft_val_t   = to_tensor(X_ft_val,   y_ft_val)
    X_test_t,     y_test_t     = to_tensor(X_test,     y_test)

    # ==== DataLoaders ====
    pt_train_loader = DataLoader(
        torch.utils.data.TensorDataset(X_train_t, y_train_t),
        batch_size=PT_BATCH_SIZE, shuffle=True, drop_last=True
    )
    pt_val_loader = DataLoader(
        torch.utils.data.TensorDataset(X_val_t, y_val_t),
        batch_size=PT_BATCH_SIZE, shuffle=False
    )
    ft_train_loader = DataLoader(
        torch.utils.data.TensorDataset(X_ft_train_t, y_ft_train_t),
        batch_size=FT_BATCH_SIZE, shuffle=True, drop_last=True
    )
    ft_val_loader = DataLoader(
        torch.utils.data.TensorDataset(X_ft_val_t, y_ft_val_t),
        batch_size=FT_BATCH_SIZE, shuffle=False
    )

    # =============================================
    # PHASE 1 — Pre-train on CODA
    # =============================================
    print(f"\n  ── Phase 1: Pre-train on CODA ({len(X_train):,} samples) ──")

    model     = MLPModel(input_dim=INPUT_SIZE, hidden_dims=HIDDEN_DIMS, dropout=DROPOUT).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=PT_LR)
    pt_es     = EarlyStopping(patience=PT_PATIENCE, mode=MODE, monitor=MONITOR, delta=DELTA, verbose=True)
    pt_history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}

    for epoch in range(PT_EPOCHS):
        model.train()
        train_loss, correct, total = 0.0, 0, 0
        for X_b, y_b in pt_train_loader:
            optimizer.zero_grad()
            out  = model(X_b)
            loss = F.binary_cross_entropy_with_logits(out, y_b)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * X_b.size(0)
            correct    += ((torch.sigmoid(out) > 0.5).float() == y_b).sum().item()
            total      += y_b.size(0)
        train_loss /= total
        train_acc   = correct / total

        model.eval()
        val_loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for X_b, y_b in pt_val_loader:
                out  = model(X_b)
                loss = F.binary_cross_entropy_with_logits(out, y_b)
                val_loss += loss.item() * X_b.size(0)
                correct  += ((torch.sigmoid(out) > 0.5).float() == y_b).sum().item()
                total    += y_b.size(0)
        val_loss /= total
        val_acc   = correct / total

        pt_history["train_loss"].append(train_loss)
        pt_history["val_loss"].append(val_loss)
        pt_history["train_acc"].append(train_acc)
        pt_history["val_acc"].append(val_acc)

        print(f"  [PT] Epoch {epoch+1:>3}/{PT_EPOCHS} | "
              f"Train Loss: {train_loss:.4f} Acc: {train_acc:.3f} | "
              f"Val Loss: {val_loss:.4f} Acc: {val_acc:.3f}")

        if pt_es(val_loss, model, epoch):
            print(f"  ⏰ Pre-train early stop at epoch {epoch+1}")
            break

    pt_es.restore_best_weights(model)   # ✅ ALWAYS restore — whether stopped early or not
    print(f"  ✅ PT best weights restored from epoch {pt_es.best_epoch + 1} "
          f"(val loss: {pt_es.best_val_loss:.4f})")

    # =============================================
    # PHASE 2 — Fine-tune on SI
    # =============================================
    print(f"\n  ── Phase 2: Fine-tune on SI ({len(X_ft_train)} samples) ──")

    ft_optimizer = torch.optim.Adam(model.parameters(), lr=FT_LR)
    ft_es        = EarlyStopping(patience=FT_PATIENCE, mode=MODE, monitor=MONITOR, delta=DELTA, verbose=True)
    ft_history   = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}

    for epoch in range(FT_EPOCHS):
        model.train()
        train_loss, correct, total = 0.0, 0, 0
        for X_b, y_b in ft_train_loader:
            ft_optimizer.zero_grad()
            out  = model(X_b)
            loss = F.binary_cross_entropy_with_logits(out, y_b)
            loss.backward()
            ft_optimizer.step()
            train_loss += loss.item() * X_b.size(0)
            correct    += ((torch.sigmoid(out) > 0.5).float() == y_b).sum().item()
            total      += y_b.size(0)
        train_loss /= total
        train_acc   = correct / total

        model.eval()
        val_loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for X_b, y_b in ft_val_loader:
                out  = model(X_b)
                loss = F.binary_cross_entropy_with_logits(out, y_b)
                val_loss += loss.item() * X_b.size(0)
                correct  += ((torch.sigmoid(out) > 0.5).float() == y_b).sum().item()
                total    += y_b.size(0)
        val_loss /= total
        val_acc   = correct / total

        ft_history["train_loss"].append(train_loss)
        ft_history["val_loss"].append(val_loss)
        ft_history["train_acc"].append(train_acc)
        ft_history["val_acc"].append(val_acc)

        print(f"  [FT] Epoch {epoch+1:>3}/{FT_EPOCHS} | "
              f"Train Loss: {train_loss:.4f} Acc: {train_acc:.3f} | "
              f"Val Loss: {val_loss:.4f} Acc: {val_acc:.3f}")

        if ft_es(val_loss, model, epoch):
            print(f"  ⏰ Fine-tune early stop at epoch {epoch+1}")
            break

    ft_es.restore_best_weights(model)   # ✅ ALWAYS restore — whether stopped early or not
    print(f"  ✅ FT best weights restored from epoch {ft_es.best_epoch + 1} "
          f"(val loss: {ft_es.best_val_loss:.4f})")

    # ==== Store results ====
    fold_data.append((X_train, y_train, X_val, y_val,
                      X_ft_train, y_ft_train, X_ft_val, y_ft_val,
                      X_test, y_test))

    all_fold_results.append({
        "fold"            : fold_idx,
        "model"           : model,           # ✅ now always holds best weights
        "pt_history"      : pt_history,
        "ft_history"      : ft_history,
        "pt_best_epoch"   : pt_es.best_epoch + 1,
        "ft_best_epoch"   : ft_es.best_epoch + 1,
        "pt_best_val_loss": pt_es.best_val_loss,
        "ft_best_val_loss": ft_es.best_val_loss,
        "X_test"          : X_test,
        "y_test"          : y_test,
    })

print("\n✅ Training Complete.")
# Out:
# ================================================================================
#   Two-Phase Training: Pre-train (CODA) → Fine-tune (SI)
#   Device: cuda
# ================================================================================
#
# ================================================================================
#   Fold 1 / 5
# ================================================================================
#
#   ── Phase 1: Pre-train on CODA (103,977 samples) ──
#   [PT] Epoch   1/30 | Train Loss: 0.3305 Acc: 0.868 | Val Loss: 1.0067 Acc: 0.542
#   ✅ Val loss improved: inf → 1.0067  (epoch 1)
#   [PT] Epoch   2/30 | Train Loss: 0.2872 Acc: 0.889 | Val Loss: 1.0932 Acc: 0.543
#   ❌ No improvement in val loss: 1.0932 (best: 1.0067)  [bad epochs: 1/10]
#   [PT] Epoch   3/30 | Train Loss: 0.2755 Acc: 0.893 | Val Loss: 1.1151 Acc: 0.551
#   ❌ No improvement in val loss: 1.1151 (best: 1.0067)  [bad epochs: 2/10]
#   [PT] Epoch   4/30 | Train Loss: 0.2665 Acc: 0.898 | Val Loss: 1.1677 Acc: 0.547
#   ❌ No improvement in val loss: 1.1677 (best: 1.0067)  [bad epochs: 3/10]
#   [PT] Epoch   5/30 | Train Loss: 0.2587 Acc: 0.901 | Val Loss: 1.1662 Acc: 0.550
#   ❌ No improvement in val loss: 1.1662 (best: 1.0067)  [bad epochs: 4/10]
#   [PT] Epoch   6/30 | Train Loss: 0.2546 Acc: 0.902 | Val Loss: 1.1577 Acc: 0.556
#   ❌ No improvement in val loss: 1.1577 (best: 1.0067)  [bad epochs: 5/10]
#   [PT] Epoch   7/30 | Train Loss: 0.2495 Acc: 0.904 | Val Loss: 1.1959 Acc: 0.552
#   ❌ No improvement in val loss: 1.1959 (best: 1.0067)  [bad epochs: 6/10]
#   [PT] Epoch   8/30 | Train Loss: 0.2462 Acc: 0.906 | Val Loss: 1.2138 Acc: 0.559
#   ❌ No improvement in val loss: 1.2138 (best: 1.0067)  [bad epochs: 7/10]
#   [PT] Epoch   9/30 | Train Loss: 0.2402 Acc: 0.909 | Val Loss: 1.1678 Acc: 0.556
#   ❌ No improvement in val loss: 1.1678 (best: 1.0067)  [bad epochs: 8/10]
#   [PT] Epoch  10/30 | Train Loss: 0.2368 Acc: 0.909 | Val Loss: 1.2135 Acc: 0.560
#   ❌ No improvement in val loss: 1.2135 (best: 1.0067)  [bad epochs: 9/10]
#   [PT] Epoch  11/30 | Train Loss: 0.2340 Acc: 0.911 | Val Loss: 1.2297 Acc: 0.558
#   ❌ No improvement in val loss: 1.2297 (best: 1.0067)  [bad epochs: 10/10]
#   ⏰ Early stopping triggered after 10 bad epochs.
#   ⏰ Pre-train early stop at epoch 11
#
# ✅ Best weights restored from epoch 1 (val loss: 1.0067)
#   ✅ PT best weights restored from epoch 1 (val loss: 1.0067)
#
#   ── Phase 2: Fine-tune on SI (258 samples) ──
#   [FT] Epoch   1/20 | Train Loss: 0.9279 Acc: 0.645 | Val Loss: 0.6986 Acc: 0.553
#   ✅ Val loss improved: inf → 0.6986  (epoch 1)
#   [FT] Epoch   2/20 | Train Loss: 0.9665 Acc: 0.660 | Val Loss: 0.7921 Acc: 0.529
#   ❌ No improvement in val loss: 0.7921 (best: 0.6986)  [bad epochs: 1/10]
#   [FT] Epoch   3/20 | Train Loss: 0.9928 Acc: 0.652 | Val Loss: 0.7959 Acc: 0.500
#   ❌ No improvement in val loss: 0.7959 (best: 0.6986)  [bad epochs: 2/10]
#   [FT] Epoch   4/20 | Train Loss: 0.8800 Acc: 0.672 | Val Loss: 0.8394 Acc: 0.453
#   ❌ No improvement in val loss: 0.8394 (best: 0.6986)  [bad epochs: 3/10]
#   [FT] Epoch   5/20 | Train Loss: 0.8721 Acc: 0.672 | Val Loss: 0.7858 Acc: 0.506
#   ❌ No improvement in val loss: 0.7858 (best: 0.6986)  [bad epochs: 4/10]
#   [FT] Epoch   6/20 | Train Loss: 0.9035 Acc: 0.633 | Val Loss: 0.7262 Acc: 0.529
#   ❌ No improvement in val loss: 0.7262 (best: 0.6986)  [bad epochs: 5/10]
#   [FT] Epoch   7/20 | Train Loss: 0.8830 Acc: 0.695 | Val Loss: 0.8008 Acc: 0.465
#   ❌ No improvement in val loss: 0.8008 (best: 0.6986)  [bad epochs: 6/10]
#   [FT] Epoch   8/20 | Train Loss: 0.9430 Acc: 0.660 | Val Loss: 0.7404 Acc: 0.512
#   ❌ No improvement in val loss: 0.7404 (best: 0.6986)  [bad epochs: 7/10]
#   [FT] Epoch   9/20 | Train Loss: 0.8134 Acc: 0.703 | Val Loss: 0.7392 Acc: 0.529
#   ❌ No improvement in val loss: 0.7392 (best: 0.6986)  [bad epochs: 8/10]
#   [FT] Epoch  10/20 | Train Loss: 0.8052 Acc: 0.699 | Val Loss: 0.6959 Acc: 0.559
#   ✅ Val loss improved: 0.6986 → 0.6959  (epoch 10)
#   [FT] Epoch  11/20 | Train Loss: 0.8410 Acc: 0.703 | Val Loss: 0.6826 Acc: 0.565
#   ✅ Val loss improved: 0.6959 → 0.6826  (epoch 11)
#   [FT] Epoch  12/20 | Train Loss: 0.7853 Acc: 0.695 | Val Loss: 0.7188 Acc: 0.512
#   ❌ No improvement in val loss: 0.7188 (best: 0.6826)  [bad epochs: 1/10]
#   [FT] Epoch  13/20 | Train Loss: 0.7156 Acc: 0.707 | Val Loss: 0.8059 Acc: 0.465
#   ❌ No improvement in val loss: 0.8059 (best: 0.6826)  [bad epochs: 2/10]
#   [FT] Epoch  14/20 | Train Loss: 0.8025 Acc: 0.672 | Val Loss: 0.7112 Acc: 0.529
#   ❌ No improvement in val loss: 0.7112 (best: 0.6826)  [bad epochs: 3/10]
#   [FT] Epoch  15/20 | Train Loss: 0.7696 Acc: 0.695 | Val Loss: 0.7451 Acc: 0.500
#   ❌ No improvement in val loss: 0.7451 (best: 0.6826)  [bad epochs: 4/10]
#   [FT] Epoch  16/20 | Train Loss: 0.7400 Acc: 0.699 | Val Loss: 0.7493 Acc: 0.500
#   ❌ No improvement in val loss: 0.7493 (best: 0.6826)  [bad epochs: 5/10]
#   [FT] Epoch  17/20 | Train Loss: 0.7260 Acc: 0.703 | Val Loss: 0.6418 Acc: 0.582
#   ✅ Val loss improved: 0.6826 → 0.6418  (epoch 17)
#   [FT] Epoch  18/20 | Train Loss: 0.6555 Acc: 0.734 | Val Loss: 0.7169 Acc: 0.518
#   ❌ No improvement in val loss: 0.7169 (best: 0.6418)  [bad epochs: 1/10]
#   [FT] Epoch  19/20 | Train Loss: 0.6729 Acc: 0.734 | Val Loss: 0.6634 Acc: 0.565
#   ❌ No improvement in val loss: 0.6634 (best: 0.6418)  [bad epochs: 2/10]
#   [FT] Epoch  20/20 | Train Loss: 0.6961 Acc: 0.707 | Val Loss: 0.7884 Acc: 0.500
#   ❌ No improvement in val loss: 0.7884 (best: 0.6418)  [bad epochs: 3/10]
#
# ✅ Best weights restored from epoch 17 (val loss: 0.6418)
#   ✅ FT best weights restored from epoch 17 (val loss: 0.6418)
#
# ================================================================================
#   Fold 2 / 5
# ================================================================================
#
#   ── Phase 1: Pre-train on CODA (114,815 samples) ──
#   [PT] Epoch   1/30 | Train Loss: 0.5122 Acc: 0.746 | Val Loss: 0.5540 Acc: 0.713
#   ✅ Val loss improved: inf → 0.5540  (epoch 1)
#   [PT] Epoch   2/30 | Train Loss: 0.4505 Acc: 0.793 | Val Loss: 0.5090 Acc: 0.736
#   ✅ Val loss improved: 0.5540 → 0.5090  (epoch 2)
#   [PT] Epoch   3/30 | Train Loss: 0.4310 Acc: 0.803 | Val Loss: 0.5344 Acc: 0.729
#   ❌ No improvement in val loss: 0.5344 (best: 0.5090)  [bad epochs: 1/10]
#   [PT] Epoch   4/30 | Train Loss: 0.4156 Acc: 0.813 | Val Loss: 0.5044 Acc: 0.744
#   ✅ Val loss improved: 0.5090 → 0.5044  (epoch 4)
#   [PT] Epoch   5/30 | Train Loss: 0.4062 Acc: 0.819 | Val Loss: 0.5069 Acc: 0.739
#   ❌ No improvement in val loss: 0.5069 (best: 0.5044)  [bad epochs: 1/10]
#   [PT] Epoch   6/30 | Train Loss: 0.3981 Acc: 0.823 | Val Loss: 0.5138 Acc: 0.737
#   ❌ No improvement in val loss: 0.5138 (best: 0.5044)  [bad epochs: 2/10]
#   [PT] Epoch   7/30 | Train Loss: 0.3933 Acc: 0.825 | Val Loss: 0.5384 Acc: 0.729
#   ❌ No improvement in val loss: 0.5384 (best: 0.5044)  [bad epochs: 3/10]
#   [PT] Epoch   8/30 | Train Loss: 0.3862 Acc: 0.830 | Val Loss: 0.5098 Acc: 0.743
#   ❌ No improvement in val loss: 0.5098 (best: 0.5044)  [bad epochs: 4/10]
#   [PT] Epoch   9/30 | Train Loss: 0.3827 Acc: 0.833 | Val Loss: 0.5289 Acc: 0.736
#   ❌ No improvement in val loss: 0.5289 (best: 0.5044)  [bad epochs: 5/10]
#   [PT] Epoch  10/30 | Train Loss: 0.3771 Acc: 0.835 | Val Loss: 0.5314 Acc: 0.733
#   ❌ No improvement in val loss: 0.5314 (best: 0.5044)  [bad epochs: 6/10]
#   [PT] Epoch  11/30 | Train Loss: 0.3700 Acc: 0.839 | Val Loss: 0.5521 Acc: 0.718
#   ❌ No improvement in val loss: 0.5521 (best: 0.5044)  [bad epochs: 7/10]
#   [PT] Epoch  12/30 | Train Loss: 0.3670 Acc: 0.840 | Val Loss: 0.5191 Acc: 0.735
#   ❌ No improvement in val loss: 0.5191 (best: 0.5044)  [bad epochs: 8/10]
#   [PT] Epoch  13/30 | Train Loss: 0.3628 Acc: 0.842 | Val Loss: 0.5258 Acc: 0.737
#   ❌ No improvement in val loss: 0.5258 (best: 0.5044)  [bad epochs: 9/10]
#   [PT] Epoch  14/30 | Train Loss: 0.3593 Acc: 0.844 | Val Loss: 0.5475 Acc: 0.733
#   ❌ No improvement in val loss: 0.5475 (best: 0.5044)  [bad epochs: 10/10]
#   ⏰ Early stopping triggered after 10 bad epochs.
#   ⏰ Pre-train early stop at epoch 14
#
# ✅ Best weights restored from epoch 4 (val loss: 0.5044)
#   ✅ PT best weights restored from epoch 4 (val loss: 0.5044)
#
#   ── Phase 2: Fine-tune on SI (252 samples) ──
#   [FT] Epoch   1/20 | Train Loss: 0.6314 Acc: 0.698 | Val Loss: 0.2410 Acc: 0.927
#   ✅ Val loss improved: inf → 0.2410  (epoch 1)
#   [FT] Epoch   2/20 | Train Loss: 0.5970 Acc: 0.730 | Val Loss: 0.2351 Acc: 0.927
#   ✅ Val loss improved: 0.2410 → 0.2351  (epoch 2)
#   [FT] Epoch   3/20 | Train Loss: 0.6160 Acc: 0.653 | Val Loss: 0.2422 Acc: 0.934
#   ❌ No improvement in val loss: 0.2422 (best: 0.2351)  [bad epochs: 1/10]
#   [FT] Epoch   4/20 | Train Loss: 0.6535 Acc: 0.706 | Val Loss: 0.2328 Acc: 0.934
#   ✅ Val loss improved: 0.2351 → 0.2328  (epoch 4)
#   [FT] Epoch   5/20 | Train Loss: 0.6250 Acc: 0.702 | Val Loss: 0.2808 Acc: 0.921
#   ❌ No improvement in val loss: 0.2808 (best: 0.2328)  [bad epochs: 1/10]
#   [FT] Epoch   6/20 | Train Loss: 0.6241 Acc: 0.722 | Val Loss: 0.2503 Acc: 0.927
#   ❌ No improvement in val loss: 0.2503 (best: 0.2328)  [bad epochs: 2/10]
#   [FT] Epoch   7/20 | Train Loss: 0.6068 Acc: 0.710 | Val Loss: 0.2722 Acc: 0.927
#   ❌ No improvement in val loss: 0.2722 (best: 0.2328)  [bad epochs: 3/10]
#   [FT] Epoch   8/20 | Train Loss: 0.5978 Acc: 0.738 | Val Loss: 0.2389 Acc: 0.927
#   ❌ No improvement in val loss: 0.2389 (best: 0.2328)  [bad epochs: 4/10]
#   [FT] Epoch   9/20 | Train Loss: 0.6438 Acc: 0.685 | Val Loss: 0.2640 Acc: 0.934
#   ❌ No improvement in val loss: 0.2640 (best: 0.2328)  [bad epochs: 5/10]
#   [FT] Epoch  10/20 | Train Loss: 0.5387 Acc: 0.734 | Val Loss: 0.2020 Acc: 0.940
#   ✅ Val loss improved: 0.2328 → 0.2020  (epoch 10)
#   [FT] Epoch  11/20 | Train Loss: 0.5626 Acc: 0.706 | Val Loss: 0.2439 Acc: 0.940
#   ❌ No improvement in val loss: 0.2439 (best: 0.2020)  [bad epochs: 1/10]
#   [FT] Epoch  12/20 | Train Loss: 0.5505 Acc: 0.746 | Val Loss: 0.2270 Acc: 0.940
#   ❌ No improvement in val loss: 0.2270 (best: 0.2020)  [bad epochs: 2/10]
#   [FT] Epoch  13/20 | Train Loss: 0.5028 Acc: 0.762 | Val Loss: 0.2639 Acc: 0.940
#   ❌ No improvement in val loss: 0.2639 (best: 0.2020)  [bad epochs: 3/10]
#   [FT] Epoch  14/20 | Train Loss: 0.4815 Acc: 0.746 | Val Loss: 0.2158 Acc: 0.947
#   ❌ No improvement in val loss: 0.2158 (best: 0.2020)  [bad epochs: 4/10]
#   [FT] Epoch  15/20 | Train Loss: 0.5179 Acc: 0.758 | Val Loss: 0.2014 Acc: 0.974
#   ❌ No improvement in val loss: 0.2014 (best: 0.2020)  [bad epochs: 5/10]
#   [FT] Epoch  16/20 | Train Loss: 0.4814 Acc: 0.762 | Val Loss: 0.2208 Acc: 0.960
#   ❌ No improvement in val loss: 0.2208 (best: 0.2020)  [bad epochs: 6/10]
#   [FT] Epoch  17/20 | Train Loss: 0.5278 Acc: 0.750 | Val Loss: 0.3257 Acc: 0.901
#   ❌ No improvement in val loss: 0.3257 (best: 0.2020)  [bad epochs: 7/10]
#   [FT] Epoch  18/20 | Train Loss: 0.5491 Acc: 0.742 | Val Loss: 0.2049 Acc: 0.954
#   ❌ No improvement in val loss: 0.2049 (best: 0.2020)  [bad epochs: 8/10]
#   [FT] Epoch  19/20 | Train Loss: 0.4828 Acc: 0.762 | Val Loss: 0.2494 Acc: 0.927
#   ❌ No improvement in val loss: 0.2494 (best: 0.2020)  [bad epochs: 9/10]
#   [FT] Epoch  20/20 | Train Loss: 0.4848 Acc: 0.754 | Val Loss: 0.1824 Acc: 0.987
#   ✅ Val loss improved: 0.2020 → 0.1824  (epoch 20)
#
# ✅ Best weights restored from epoch 20 (val loss: 0.1824)
#   ✅ FT best weights restored from epoch 20 (val loss: 0.1824)
#
# ================================================================================
#   Fold 3 / 5
# ================================================================================
#
#   ── Phase 1: Pre-train on CODA (97,072 samples) ──
#   [PT] Epoch   1/30 | Train Loss: 0.4396 Acc: 0.787 | Val Loss: 0.8716 Acc: 0.571
#   ✅ Val loss improved: inf → 0.8716  (epoch 1)
#   [PT] Epoch   2/30 | Train Loss: 0.3851 Acc: 0.821 | Val Loss: 0.8889 Acc: 0.577
#   ❌ No improvement in val loss: 0.8889 (best: 0.8716)  [bad epochs: 1/10]
#   [PT] Epoch   3/30 | Train Loss: 0.3674 Acc: 0.832 | Val Loss: 0.8364 Acc: 0.605
#   ✅ Val loss improved: 0.8716 → 0.8364  (epoch 3)
#   [PT] Epoch   4/30 | Train Loss: 0.3566 Acc: 0.839 | Val Loss: 0.8507 Acc: 0.603
#   ❌ No improvement in val loss: 0.8507 (best: 0.8364)  [bad epochs: 1/10]
#   [PT] Epoch   5/30 | Train Loss: 0.3471 Acc: 0.844 | Val Loss: 0.8759 Acc: 0.599
#   ❌ No improvement in val loss: 0.8759 (best: 0.8364)  [bad epochs: 2/10]
#   [PT] Epoch   6/30 | Train Loss: 0.3406 Acc: 0.848 | Val Loss: 0.8821 Acc: 0.602
#   ❌ No improvement in val loss: 0.8821 (best: 0.8364)  [bad epochs: 3/10]
#   [PT] Epoch   7/30 | Train Loss: 0.3365 Acc: 0.850 | Val Loss: 0.8040 Acc: 0.612
#   ✅ Val loss improved: 0.8364 → 0.8040  (epoch 7)
#   [PT] Epoch   8/30 | Train Loss: 0.3302 Acc: 0.854 | Val Loss: 0.9941 Acc: 0.594
#   ❌ No improvement in val loss: 0.9941 (best: 0.8040)  [bad epochs: 1/10]
#   [PT] Epoch   9/30 | Train Loss: 0.3256 Acc: 0.855 | Val Loss: 0.8491 Acc: 0.613
#   ❌ No improvement in val loss: 0.8491 (best: 0.8040)  [bad epochs: 2/10]
#   [PT] Epoch  10/30 | Train Loss: 0.3229 Acc: 0.858 | Val Loss: 0.8215 Acc: 0.607
#   ❌ No improvement in val loss: 0.8215 (best: 0.8040)  [bad epochs: 3/10]
#   [PT] Epoch  11/30 | Train Loss: 0.3194 Acc: 0.860 | Val Loss: 0.9522 Acc: 0.595
#   ❌ No improvement in val loss: 0.9522 (best: 0.8040)  [bad epochs: 4/10]
#   [PT] Epoch  12/30 | Train Loss: 0.3152 Acc: 0.861 | Val Loss: 0.8299 Acc: 0.619
#   ❌ No improvement in val loss: 0.8299 (best: 0.8040)  [bad epochs: 5/10]
#   [PT] Epoch  13/30 | Train Loss: 0.3129 Acc: 0.864 | Val Loss: 0.9335 Acc: 0.606
#   ❌ No improvement in val loss: 0.9335 (best: 0.8040)  [bad epochs: 6/10]
#   [PT] Epoch  14/30 | Train Loss: 0.3114 Acc: 0.864 | Val Loss: 0.8060 Acc: 0.618
#   ❌ No improvement in val loss: 0.8060 (best: 0.8040)  [bad epochs: 7/10]
#   [PT] Epoch  15/30 | Train Loss: 0.3112 Acc: 0.865 | Val Loss: 0.9068 Acc: 0.601
#   ❌ No improvement in val loss: 0.9068 (best: 0.8040)  [bad epochs: 8/10]
#   [PT] Epoch  16/30 | Train Loss: 0.3068 Acc: 0.867 | Val Loss: 0.9035 Acc: 0.602
#   ❌ No improvement in val loss: 0.9035 (best: 0.8040)  [bad epochs: 9/10]
#   [PT] Epoch  17/30 | Train Loss: 0.3058 Acc: 0.866 | Val Loss: 0.8725 Acc: 0.611
#   ❌ No improvement in val loss: 0.8725 (best: 0.8040)  [bad epochs: 10/10]
#   ⏰ Early stopping triggered after 10 bad epochs.
#   ⏰ Pre-train early stop at epoch 17
#
# ✅ Best weights restored from epoch 7 (val loss: 0.8040)
#   ✅ PT best weights restored from epoch 7 (val loss: 0.8040)
#
#   ── Phase 2: Fine-tune on SI (302 samples) ──
#   [FT] Epoch   1/20 | Train Loss: 0.8428 Acc: 0.618 | Val Loss: 1.5140 Acc: 0.143
#   ✅ Val loss improved: inf → 1.5140  (epoch 1)
#   [FT] Epoch   2/20 | Train Loss: 0.8962 Acc: 0.622 | Val Loss: 1.3939 Acc: 0.200
#   ✅ Val loss improved: 1.5140 → 1.3939  (epoch 2)
#   [FT] Epoch   3/20 | Train Loss: 0.8674 Acc: 0.649 | Val Loss: 1.4513 Acc: 0.229
#   ❌ No improvement in val loss: 1.4513 (best: 1.3939)  [bad epochs: 1/10]
#   [FT] Epoch   4/20 | Train Loss: 0.8308 Acc: 0.655 | Val Loss: 1.4332 Acc: 0.143
#   ❌ No improvement in val loss: 1.4332 (best: 1.3939)  [bad epochs: 2/10]
#   [FT] Epoch   5/20 | Train Loss: 0.7277 Acc: 0.659 | Val Loss: 1.3779 Acc: 0.243
#   ✅ Val loss improved: 1.3939 → 1.3779  (epoch 5)
#   [FT] Epoch   6/20 | Train Loss: 0.7493 Acc: 0.645 | Val Loss: 1.4679 Acc: 0.186
#   ❌ No improvement in val loss: 1.4679 (best: 1.3779)  [bad epochs: 1/10]
#   [FT] Epoch   7/20 | Train Loss: 0.6715 Acc: 0.686 | Val Loss: 1.4468 Acc: 0.171
#   ❌ No improvement in val loss: 1.4468 (best: 1.3779)  [bad epochs: 2/10]
#   [FT] Epoch   8/20 | Train Loss: 0.8034 Acc: 0.672 | Val Loss: 1.3595 Acc: 0.186
#   ✅ Val loss improved: 1.3779 → 1.3595  (epoch 8)
#   [FT] Epoch   9/20 | Train Loss: 0.7520 Acc: 0.676 | Val Loss: 1.2801 Acc: 0.143
#   ✅ Val loss improved: 1.3595 → 1.2801  (epoch 9)
#   [FT] Epoch  10/20 | Train Loss: 0.6888 Acc: 0.689 | Val Loss: 1.3694 Acc: 0.171
#   ❌ No improvement in val loss: 1.3694 (best: 1.2801)  [bad epochs: 1/10]
#   [FT] Epoch  11/20 | Train Loss: 0.7588 Acc: 0.649 | Val Loss: 1.3110 Acc: 0.186
#   ❌ No improvement in val loss: 1.3110 (best: 1.2801)  [bad epochs: 2/10]
#   [FT] Epoch  12/20 | Train Loss: 0.7272 Acc: 0.689 | Val Loss: 1.2979 Acc: 0.157
#   ❌ No improvement in val loss: 1.2979 (best: 1.2801)  [bad epochs: 3/10]
#   [FT] Epoch  13/20 | Train Loss: 0.7720 Acc: 0.649 | Val Loss: 1.3220 Acc: 0.171
#   ❌ No improvement in val loss: 1.3220 (best: 1.2801)  [bad epochs: 4/10]
#   [FT] Epoch  14/20 | Train Loss: 0.7193 Acc: 0.672 | Val Loss: 1.3025 Acc: 0.171
#   ❌ No improvement in val loss: 1.3025 (best: 1.2801)  [bad epochs: 5/10]
#   [FT] Epoch  15/20 | Train Loss: 0.6105 Acc: 0.716 | Val Loss: 1.3400 Acc: 0.171
#   ❌ No improvement in val loss: 1.3400 (best: 1.2801)  [bad epochs: 6/10]
#   [FT] Epoch  16/20 | Train Loss: 0.7140 Acc: 0.706 | Val Loss: 1.3993 Acc: 0.186
#   ❌ No improvement in val loss: 1.3993 (best: 1.2801)  [bad epochs: 7/10]
#   [FT] Epoch  17/20 | Train Loss: 0.5685 Acc: 0.733 | Val Loss: 1.2604 Acc: 0.171
#   ✅ Val loss improved: 1.2801 → 1.2604  (epoch 17)
#   [FT] Epoch  18/20 | Train Loss: 0.6670 Acc: 0.730 | Val Loss: 1.3108 Acc: 0.186
#   ❌ No improvement in val loss: 1.3108 (best: 1.2604)  [bad epochs: 1/10]
#   [FT] Epoch  19/20 | Train Loss: 0.7003 Acc: 0.693 | Val Loss: 1.2998 Acc: 0.186
#   ❌ No improvement in val loss: 1.2998 (best: 1.2604)  [bad epochs: 2/10]
#   [FT] Epoch  20/20 | Train Loss: 0.5949 Acc: 0.713 | Val Loss: 1.3440 Acc: 0.171
#   ❌ No improvement in val loss: 1.3440 (best: 1.2604)  [bad epochs: 3/10]
#
# ✅ Best weights restored from epoch 17 (val loss: 1.2604)
#   ✅ FT best weights restored from epoch 17 (val loss: 1.2604)
#
# ================================================================================
#   Fold 4 / 5
# ================================================================================
#
#   ── Phase 1: Pre-train on CODA (107,575 samples) ──
#   [PT] Epoch   1/30 | Train Loss: 0.4766 Acc: 0.770 | Val Loss: 0.6627 Acc: 0.747
#   ✅ Val loss improved: inf → 0.6627  (epoch 1)
#   [PT] Epoch   2/30 | Train Loss: 0.4195 Acc: 0.807 | Val Loss: 0.6739 Acc: 0.728
#   ❌ No improvement in val loss: 0.6739 (best: 0.6627)  [bad epochs: 1/10]
#   [PT] Epoch   3/30 | Train Loss: 0.4005 Acc: 0.818 | Val Loss: 0.6982 Acc: 0.734
#   ❌ No improvement in val loss: 0.6982 (best: 0.6627)  [bad epochs: 2/10]
#   [PT] Epoch   4/30 | Train Loss: 0.3884 Acc: 0.825 | Val Loss: 0.7468 Acc: 0.737
#   ❌ No improvement in val loss: 0.7468 (best: 0.6627)  [bad epochs: 3/10]
#   [PT] Epoch   5/30 | Train Loss: 0.3786 Acc: 0.831 | Val Loss: 0.6999 Acc: 0.746
#   ❌ No improvement in val loss: 0.6999 (best: 0.6627)  [bad epochs: 4/10]
#   [PT] Epoch   6/30 | Train Loss: 0.3704 Acc: 0.836 | Val Loss: 0.7419 Acc: 0.744
#   ❌ No improvement in val loss: 0.7419 (best: 0.6627)  [bad epochs: 5/10]
#   [PT] Epoch   7/30 | Train Loss: 0.3645 Acc: 0.838 | Val Loss: 0.7246 Acc: 0.721
#   ❌ No improvement in val loss: 0.7246 (best: 0.6627)  [bad epochs: 6/10]
#   [PT] Epoch   8/30 | Train Loss: 0.3589 Acc: 0.841 | Val Loss: 0.7100 Acc: 0.744
#   ❌ No improvement in val loss: 0.7100 (best: 0.6627)  [bad epochs: 7/10]
#   [PT] Epoch   9/30 | Train Loss: 0.3561 Acc: 0.843 | Val Loss: 0.7408 Acc: 0.750
#   ❌ No improvement in val loss: 0.7408 (best: 0.6627)  [bad epochs: 8/10]
#   [PT] Epoch  10/30 | Train Loss: 0.3499 Acc: 0.846 | Val Loss: 0.7817 Acc: 0.755
#   ❌ No improvement in val loss: 0.7817 (best: 0.6627)  [bad epochs: 9/10]
#   [PT] Epoch  11/30 | Train Loss: 0.3467 Acc: 0.849 | Val Loss: 0.6964 Acc: 0.745
#   ❌ No improvement in val loss: 0.6964 (best: 0.6627)  [bad epochs: 10/10]
#   ⏰ Early stopping triggered after 10 bad epochs.
#   ⏰ Pre-train early stop at epoch 11
#
# ✅ Best weights restored from epoch 1 (val loss: 0.6627)
#   ✅ PT best weights restored from epoch 1 (val loss: 0.6627)
#
#   ── Phase 2: Fine-tune on SI (386 samples) ──
#   [FT] Epoch   1/20 | Train Loss: 0.6770 Acc: 0.706 | Val Loss: 0.6065 Acc: 0.718
#   ✅ Val loss improved: inf → 0.6065  (epoch 1)
#   [FT] Epoch   2/20 | Train Loss: 0.6080 Acc: 0.724 | Val Loss: 0.6107 Acc: 0.718
#   ❌ No improvement in val loss: 0.6107 (best: 0.6065)  [bad epochs: 1/10]
#   [FT] Epoch   3/20 | Train Loss: 0.6098 Acc: 0.706 | Val Loss: 0.6560 Acc: 0.704
#   ❌ No improvement in val loss: 0.6560 (best: 0.6065)  [bad epochs: 2/10]
#   [FT] Epoch   4/20 | Train Loss: 0.5924 Acc: 0.721 | Val Loss: 0.5821 Acc: 0.718
#   ✅ Val loss improved: 0.6065 → 0.5821  (epoch 4)
#   [FT] Epoch   5/20 | Train Loss: 0.5665 Acc: 0.755 | Val Loss: 0.5598 Acc: 0.718
#   ✅ Val loss improved: 0.5821 → 0.5598  (epoch 5)
#   [FT] Epoch   6/20 | Train Loss: 0.5350 Acc: 0.734 | Val Loss: 0.5497 Acc: 0.704
#   ✅ Val loss improved: 0.5598 → 0.5497  (epoch 6)
#   [FT] Epoch   7/20 | Train Loss: 0.5168 Acc: 0.789 | Val Loss: 0.5178 Acc: 0.746
#   ✅ Val loss improved: 0.5497 → 0.5178  (epoch 7)
#   [FT] Epoch   8/20 | Train Loss: 0.5212 Acc: 0.771 | Val Loss: 0.5253 Acc: 0.732
#   ❌ No improvement in val loss: 0.5253 (best: 0.5178)  [bad epochs: 1/10]
#   [FT] Epoch   9/20 | Train Loss: 0.5203 Acc: 0.771 | Val Loss: 0.4740 Acc: 0.746
#   ✅ Val loss improved: 0.5178 → 0.4740  (epoch 9)
#   [FT] Epoch  10/20 | Train Loss: 0.5077 Acc: 0.779 | Val Loss: 0.5077 Acc: 0.746
#   ❌ No improvement in val loss: 0.5077 (best: 0.4740)  [bad epochs: 1/10]
#   [FT] Epoch  11/20 | Train Loss: 0.5082 Acc: 0.781 | Val Loss: 0.5099 Acc: 0.746
#   ❌ No improvement in val loss: 0.5099 (best: 0.4740)  [bad epochs: 2/10]
#   [FT] Epoch  12/20 | Train Loss: 0.4764 Acc: 0.784 | Val Loss: 0.5119 Acc: 0.690
#   ❌ No improvement in val loss: 0.5119 (best: 0.4740)  [bad epochs: 3/10]
#   [FT] Epoch  13/20 | Train Loss: 0.4764 Acc: 0.789 | Val Loss: 0.4978 Acc: 0.718
#   ❌ No improvement in val loss: 0.4978 (best: 0.4740)  [bad epochs: 4/10]
#   [FT] Epoch  14/20 | Train Loss: 0.4768 Acc: 0.771 | Val Loss: 0.4832 Acc: 0.732
#   ❌ No improvement in val loss: 0.4832 (best: 0.4740)  [bad epochs: 5/10]
#   [FT] Epoch  15/20 | Train Loss: 0.4426 Acc: 0.797 | Val Loss: 0.4692 Acc: 0.746
#   ✅ Val loss improved: 0.4740 → 0.4692  (epoch 15)
#   [FT] Epoch  16/20 | Train Loss: 0.4650 Acc: 0.820 | Val Loss: 0.4454 Acc: 0.761
#   ✅ Val loss improved: 0.4692 → 0.4454  (epoch 16)
#   [FT] Epoch  17/20 | Train Loss: 0.4634 Acc: 0.812 | Val Loss: 0.4900 Acc: 0.704
#   ❌ No improvement in val loss: 0.4900 (best: 0.4454)  [bad epochs: 1/10]
#   [FT] Epoch  18/20 | Train Loss: 0.4431 Acc: 0.815 | Val Loss: 0.4552 Acc: 0.746
#   ❌ No improvement in val loss: 0.4552 (best: 0.4454)  [bad epochs: 2/10]
#   [FT] Epoch  19/20 | Train Loss: 0.4259 Acc: 0.815 | Val Loss: 0.4508 Acc: 0.761
#   ❌ No improvement in val loss: 0.4508 (best: 0.4454)  [bad epochs: 3/10]
#   [FT] Epoch  20/20 | Train Loss: 0.4074 Acc: 0.828 | Val Loss: 0.4287 Acc: 0.775
#   ✅ Val loss improved: 0.4454 → 0.4287  (epoch 20)
#
# ✅ Best weights restored from epoch 20 (val loss: 0.4287)
#   ✅ FT best weights restored from epoch 20 (val loss: 0.4287)
#
# ================================================================================
#   Fold 5 / 5
# ================================================================================
#
#   ── Phase 1: Pre-train on CODA (103,501 samples) ──
#   [PT] Epoch   1/30 | Train Loss: 0.4532 Acc: 0.780 | Val Loss: 0.9471 Acc: 0.573
#   ✅ Val loss improved: inf → 0.9471  (epoch 1)
#   [PT] Epoch   2/30 | Train Loss: 0.4047 Acc: 0.811 | Val Loss: 0.8698 Acc: 0.592
#   ✅ Val loss improved: 0.9471 → 0.8698  (epoch 2)
#   [PT] Epoch   3/30 | Train Loss: 0.3868 Acc: 0.823 | Val Loss: 0.9156 Acc: 0.587
#   ❌ No improvement in val loss: 0.9156 (best: 0.8698)  [bad epochs: 1/10]
#   [PT] Epoch   4/30 | Train Loss: 0.3756 Acc: 0.830 | Val Loss: 0.9352 Acc: 0.587
#   ❌ No improvement in val loss: 0.9352 (best: 0.8698)  [bad epochs: 2/10]
#   [PT] Epoch   5/30 | Train Loss: 0.3658 Acc: 0.836 | Val Loss: 0.8533 Acc: 0.604
#   ✅ Val loss improved: 0.8698 → 0.8533  (epoch 5)
#   [PT] Epoch   6/30 | Train Loss: 0.3607 Acc: 0.839 | Val Loss: 0.8918 Acc: 0.581
#   ❌ No improvement in val loss: 0.8918 (best: 0.8533)  [bad epochs: 1/10]
#   [PT] Epoch   7/30 | Train Loss: 0.3552 Acc: 0.842 | Val Loss: 0.8655 Acc: 0.611
#   ❌ No improvement in val loss: 0.8655 (best: 0.8533)  [bad epochs: 2/10]
#   [PT] Epoch   8/30 | Train Loss: 0.3480 Acc: 0.846 | Val Loss: 1.0301 Acc: 0.580
#   ❌ No improvement in val loss: 1.0301 (best: 0.8533)  [bad epochs: 3/10]
#   [PT] Epoch   9/30 | Train Loss: 0.3438 Acc: 0.849 | Val Loss: 0.9914 Acc: 0.587
#   ❌ No improvement in val loss: 0.9914 (best: 0.8533)  [bad epochs: 4/10]
#   [PT] Epoch  10/30 | Train Loss: 0.3397 Acc: 0.851 | Val Loss: 0.9239 Acc: 0.601
#   ❌ No improvement in val loss: 0.9239 (best: 0.8533)  [bad epochs: 5/10]
#   [PT] Epoch  11/30 | Train Loss: 0.3364 Acc: 0.853 | Val Loss: 0.9383 Acc: 0.602
#   ❌ No improvement in val loss: 0.9383 (best: 0.8533)  [bad epochs: 6/10]
#   [PT] Epoch  12/30 | Train Loss: 0.3341 Acc: 0.855 | Val Loss: 0.9100 Acc: 0.591
#   ❌ No improvement in val loss: 0.9100 (best: 0.8533)  [bad epochs: 7/10]
#   [PT] Epoch  13/30 | Train Loss: 0.3303 Acc: 0.855 | Val Loss: 0.9493 Acc: 0.581
#   ❌ No improvement in val loss: 0.9493 (best: 0.8533)  [bad epochs: 8/10]
#   [PT] Epoch  14/30 | Train Loss: 0.3297 Acc: 0.857 | Val Loss: 1.0488 Acc: 0.582
#   ❌ No improvement in val loss: 1.0488 (best: 0.8533)  [bad epochs: 9/10]
#   [PT] Epoch  15/30 | Train Loss: 0.3259 Acc: 0.858 | Val Loss: 0.9779 Acc: 0.591
#   ❌ No improvement in val loss: 0.9779 (best: 0.8533)  [bad epochs: 10/10]
#   ⏰ Early stopping triggered after 10 bad epochs.
#   ⏰ Pre-train early stop at epoch 15
#
# ✅ Best weights restored from epoch 5 (val loss: 0.8533)
#   ✅ PT best weights restored from epoch 5 (val loss: 0.8533)
#
#   ── Phase 2: Fine-tune on SI (278 samples) ──
#   [FT] Epoch   1/20 | Train Loss: 0.6836 Acc: 0.688 | Val Loss: 0.3061 Acc: 0.845
#   ✅ Val loss improved: inf → 0.3061  (epoch 1)
#   [FT] Epoch   2/20 | Train Loss: 0.6964 Acc: 0.669 | Val Loss: 0.3261 Acc: 0.809
#   ❌ No improvement in val loss: 0.3261 (best: 0.3061)  [bad epochs: 1/10]
#   [FT] Epoch   3/20 | Train Loss: 0.6245 Acc: 0.706 | Val Loss: 0.3037 Acc: 0.827
#   ✅ Val loss improved: 0.3061 → 0.3037  (epoch 3)
#   [FT] Epoch   4/20 | Train Loss: 0.6448 Acc: 0.706 | Val Loss: 0.2963 Acc: 0.845
#   ✅ Val loss improved: 0.3037 → 0.2963  (epoch 4)
#   [FT] Epoch   5/20 | Train Loss: 0.5757 Acc: 0.735 | Val Loss: 0.3010 Acc: 0.827
#   ❌ No improvement in val loss: 0.3010 (best: 0.2963)  [bad epochs: 1/10]
#   [FT] Epoch   6/20 | Train Loss: 0.6085 Acc: 0.739 | Val Loss: 0.2997 Acc: 0.836
#   ❌ No improvement in val loss: 0.2997 (best: 0.2963)  [bad epochs: 2/10]
#   [FT] Epoch   7/20 | Train Loss: 0.6148 Acc: 0.717 | Val Loss: 0.2758 Acc: 0.855
#   ✅ Val loss improved: 0.2963 → 0.2758  (epoch 7)
#   [FT] Epoch   8/20 | Train Loss: 0.6111 Acc: 0.691 | Val Loss: 0.2910 Acc: 0.827
#   ❌ No improvement in val loss: 0.2910 (best: 0.2758)  [bad epochs: 1/10]
#   [FT] Epoch   9/20 | Train Loss: 0.5960 Acc: 0.710 | Val Loss: 0.2815 Acc: 0.836
#   ❌ No improvement in val loss: 0.2815 (best: 0.2758)  [bad epochs: 2/10]
#   [FT] Epoch  10/20 | Train Loss: 0.5529 Acc: 0.761 | Val Loss: 0.2741 Acc: 0.855
#   ✅ Val loss improved: 0.2758 → 0.2741  (epoch 10)
#   [FT] Epoch  11/20 | Train Loss: 0.5641 Acc: 0.702 | Val Loss: 0.2645 Acc: 0.845
#   ✅ Val loss improved: 0.2741 → 0.2645  (epoch 11)
#   [FT] Epoch  12/20 | Train Loss: 0.5087 Acc: 0.754 | Val Loss: 0.2772 Acc: 0.873
#   ❌ No improvement in val loss: 0.2772 (best: 0.2645)  [bad epochs: 1/10]
#   [FT] Epoch  13/20 | Train Loss: 0.4832 Acc: 0.757 | Val Loss: 0.2841 Acc: 0.864
#   ❌ No improvement in val loss: 0.2841 (best: 0.2645)  [bad epochs: 2/10]
#   [FT] Epoch  14/20 | Train Loss: 0.4637 Acc: 0.765 | Val Loss: 0.2747 Acc: 0.845
#   ❌ No improvement in val loss: 0.2747 (best: 0.2645)  [bad epochs: 3/10]
#   [FT] Epoch  15/20 | Train Loss: 0.4953 Acc: 0.761 | Val Loss: 0.2996 Acc: 0.836
#   ❌ No improvement in val loss: 0.2996 (best: 0.2645)  [bad epochs: 4/10]
#   [FT] Epoch  16/20 | Train Loss: 0.3945 Acc: 0.816 | Val Loss: 0.2777 Acc: 0.855
#   ❌ No improvement in val loss: 0.2777 (best: 0.2645)  [bad epochs: 5/10]
#   [FT] Epoch  17/20 | Train Loss: 0.4536 Acc: 0.801 | Val Loss: 0.2767 Acc: 0.836
#   ❌ No improvement in val loss: 0.2767 (best: 0.2645)  [bad epochs: 6/10]
#   [FT] Epoch  18/20 | Train Loss: 0.4781 Acc: 0.783 | Val Loss: 0.2815 Acc: 0.855
#   ❌ No improvement in val loss: 0.2815 (best: 0.2645)  [bad epochs: 7/10]
#   [FT] Epoch  19/20 | Train Loss: 0.4345 Acc: 0.794 | Val Loss: 0.2590 Acc: 0.864
#   ✅ Val loss improved: 0.2645 → 0.2590  (epoch 19)
#   [FT] Epoch  20/20 | Train Loss: 0.4359 Acc: 0.779 | Val Loss: 0.2751 Acc: 0.855
#   ❌ No improvement in val loss: 0.2751 (best: 0.2590)  [bad epochs: 1/10]
#
# ✅ Best weights restored from epoch 19 (val loss: 0.2590)
#   ✅ FT best weights restored from epoch 19 (val loss: 0.2590)
#
# ✅ Training Complete.

# %% [markdown]
# ### Visualization of Early Stopping Training per Fold

# %%
# ============================================================
#   Visualization of Early Stopping Training per Fold
#   Shows Phase 1 (CODA pre-train) + Phase 2 (SI fine-tune)
# ============================================================

fig, axes = plt.subplots(
    nrows   = n_folds,
    ncols   = 4,              # Loss PT | Acc PT | Loss FT | Acc FT
    figsize = (20, 4 * n_folds),
)

fig.suptitle(
    "Training Curves per Fold — Phase 1: Pre-train (CODA) | Phase 2: Fine-tune (SI)",
    fontsize=14, fontweight="bold", y=1.01
)

COLOR_TRAIN = "#4C72B0"
COLOR_VAL   = "#DD8452"
COLOR_BEST  = "red"

for i, result in enumerate(all_fold_results):
    fold_num     = result["fold"]
    pt_history   = result["pt_history"]
    ft_history   = result["ft_history"]
    pt_best      = result["pt_best_epoch"]   # already +1 from training cell
    ft_best      = result["ft_best_epoch"]

    pt_epochs = range(1, len(pt_history["train_loss"]) + 1)
    ft_epochs = range(1, len(ft_history["train_loss"]) + 1)

    # ── Phase 1 Loss ──────────────────────────────────────────
    ax = axes[i, 0]
    ax.plot(pt_epochs, pt_history["train_loss"], label="Train", color=COLOR_TRAIN, lw=2)
    ax.plot(pt_epochs, pt_history["val_loss"],   label="Val",   color=COLOR_VAL,   lw=2)
    ax.axvline(pt_best, color=COLOR_BEST, linestyle="--", lw=1.5, label=f"Best ({pt_best})")
    ax.set_title(f"Fold {fold_num} · PT Loss (CODA)", fontsize=10, fontweight="bold")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("BCE Loss")
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)

    # ── Phase 1 Accuracy ──────────────────────────────────────
    ax = axes[i, 1]
    ax.plot(pt_epochs, pt_history["train_acc"], label="Train", color=COLOR_TRAIN, lw=2)
    ax.plot(pt_epochs, pt_history["val_acc"],   label="Val",   color=COLOR_VAL,   lw=2)
    ax.axvline(pt_best, color=COLOR_BEST, linestyle="--", lw=1.5, label=f"Best ({pt_best})")
    ax.set_title(f"Fold {fold_num} · PT Accuracy (CODA)", fontsize=10, fontweight="bold")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Accuracy")
    ax.set_ylim([0, 1.05])
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)

    # ── Phase 2 Loss ──────────────────────────────────────────
    ax = axes[i, 2]
    ax.plot(ft_epochs, ft_history["train_loss"], label="Train", color=COLOR_TRAIN, lw=2)
    ax.plot(ft_epochs, ft_history["val_loss"],   label="Val",   color=COLOR_VAL,   lw=2)
    ax.axvline(ft_best, color=COLOR_BEST, linestyle="--", lw=1.5, label=f"Best ({ft_best})")
    ax.set_title(f"Fold {fold_num} · FT Loss (SI)", fontsize=10, fontweight="bold")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("BCE Loss")
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)

    # ── Phase 2 Accuracy ──────────────────────────────────────
    ax = axes[i, 3]
    ax.plot(ft_epochs, ft_history["train_acc"], label="Train", color=COLOR_TRAIN, lw=2)
    ax.plot(ft_epochs, ft_history["val_acc"],   label="Val",   color=COLOR_VAL,   lw=2)
    ax.axvline(ft_best, color=COLOR_BEST, linestyle="--", lw=1.5, label=f"Best ({ft_best})")
    ax.set_title(f"Fold {fold_num} · FT Accuracy (SI)", fontsize=10, fontweight="bold")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Accuracy")
    ax.set_ylim([0, 1.05])
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Evaluation Model**

# %% [markdown]
# ### Evaluation with Classification Report per Fold

# %%
fold_probs   = []
fold_y_tests = []

for fold_idx, result in enumerate(all_fold_results):
    model  = result["model"]
    X_test = result["X_test"]       
    y_test = result["y_test"]

    X_test_t = torch.FloatTensor(X_test).to(DEVICE)

    model.eval()
    with torch.no_grad():
        logits = model(X_test_t).squeeze().cpu().numpy()

    probs = 1 / (1 + np.exp(-logits))
    fold_probs.append(probs)
    fold_y_tests.append(np.asarray(y_test).astype(int))

fold_probs     = np.array(fold_probs, dtype=object)  # ragged — folds have diff test sizes
print(f"✅ Predictions from {len(fold_probs)} folds  "
      f"({sum(len(y) for y in fold_y_tests)} total test samples)")
# Out:
# ✅ Predictions from 5 folds  (512 total test samples)

# %%
print("\n" + "="*80)
print("SUMMARY OF ALL FOLDS (Per-Fold Test Performance)")
print("="*80 + "\n")

fold_summary = []

for i, (probs, y_true, result) in enumerate(
        zip(fold_probs, fold_y_tests, all_fold_results), start=1):

    fpr, tpr, thresholds = roc_curve(y_true, probs)
    j_idx  = np.argmax(tpr - fpr)
    thresh = float(thresholds[j_idx])

    preds          = (probs >= thresh).astype(int)
    cm_mat         = confusion_matrix(y_true, preds)
    tn, fp, fn, tp = cm_mat.ravel()
    sens  = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    spec  = tn / (tn + fp) if (tn + fp) > 0 else 0.0
    auroc = roc_auc_score(y_true, probs)
    auprc = average_precision_score(y_true, probs)
    acc   = accuracy_score(y_true, preds)
    f1    = f1_score(y_true, preds, zero_division=0) 

    fold_summary.append({
        "Fold"        : i,
        "AUROC"       : f"{auroc:.4f}",
        "AUPRC"       : f"{auprc:.4f}",
        "Sensitivity" : f"{sens:.3f}",
        "Specificity" : f"{spec:.3f}",
        "Threshold"   : f"{thresh:.4f}",
        "PT Best Epoch": result["pt_best_epoch"],   # ✅ pre-train best
        "FT Best Epoch": result["ft_best_epoch"],   # ✅ fine-tune best
        "_auroc": auroc, "_auprc": auprc, "_sens": sens, "_spec": spec, "_acc": acc, "_f1": f1
    })

cols = ["Fold", "AUROC", "AUPRC", "Sensitivity", "Specificity",
        "Threshold", "PT Best Epoch", "FT Best Epoch"]
print(pd.DataFrame(fold_summary)[cols].to_string(index=False))

aurocs = [r["_auroc"] for r in fold_summary]
auprcs = [r["_auprc"] for r in fold_summary]
accs   = [r["_acc"] for r in fold_summary]
f1s    = [r["_f1"] for r in fold_summary]
senss  = [r["_sens"]  for r in fold_summary]
specs  = [r["_spec"]  for r in fold_summary]


print(f"\n{'-'*80}")
print(f"Mean AUROC       : {np.mean(aurocs):.4f} ± {np.std(aurocs):.4f}")
print(f"Mean AUPRC       : {np.mean(auprcs):.4f} ± {np.std(auprcs):.4f}")
print(f"Mean Accuracy    : {np.mean(accs):.4f} ± {np.std(accs):.4f}")
print(f"Mean F1 Score    : {np.mean(f1s):.4f} ± {np.std(f1s):.4f}")
print(f"Mean Sensitivity : {np.mean(senss):.3f} ± {np.std(senss):.3f}")
print(f"Mean Specificity : {np.mean(specs):.3f} ± {np.std(specs):.3f}")
print(f"{'-'*80}")
# Out:
# ================================================================================
# SUMMARY OF ALL FOLDS (Per-Fold Test Performance)
# ================================================================================
#
#  Fold  AUROC  AUPRC Sensitivity Specificity Threshold  PT Best Epoch  FT Best Epoch
#     1 0.9870 0.9876       1.000       0.881    0.1780              1             17
#     2 0.8239 0.6160       1.000       0.611    0.2913              4             20
#     3 0.8813 0.4756       0.950       0.783    0.3604              7             17
#     4 1.0000 1.0000       1.000       1.000    0.3814              1             20
#     5 0.7917 0.8913       0.663       0.780    0.1578              5             19
#
# --------------------------------------------------------------------------------
# Mean AUROC       : 0.8968 ± 0.0841
# Mean AUPRC       : 0.7941 ± 0.2109
# Mean Accuracy    : 0.8385 ± 0.1143
# Mean F1 Score    : 0.8004 ± 0.1519
# Mean Sensitivity : 0.923 ± 0.131
# Mean Specificity : 0.811 ± 0.128
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Visualization of Evaluation with AUROC Curves and Confusion Matrix per Fold

# %%
# ── ROC curves + confusion matrices ────────────────────────────────────────────
FOLD_COLORS = ["#00BFFF", "#FFA500", "#FF0000", "#32CD32", "#8A2BE2"]
mean_fpr = np.linspace(0, 1, 200)
fold_fprs, fold_tprs, fold_aucs = [], [], []

for y_true, probs in zip(fold_y_tests, fold_probs):
    fpr, tpr, _ = roc_curve(y_true, probs)
    fold_fprs.append(fpr); fold_tprs.append(tpr); fold_aucs.append(auc(fpr, tpr))

interp_tprs = [np.interp(mean_fpr, f, t) for f, t in zip(fold_fprs, fold_tprs)]
mean_tpr    = np.mean(interp_tprs, axis=0); mean_tpr[0] = 0.0
mean_auc    = auc(mean_fpr, mean_tpr); std_auc = np.std(fold_aucs)      

fig = plt.figure(figsize=(14, 8))
gs  = gridspec.GridSpec(1, 2, width_ratios=[1.4, 1], wspace=0.35)

# LEFT: ROC
ax_roc = fig.add_subplot(gs[0])
for i, (fpr, tpr, a) in enumerate(zip(fold_fprs, fold_tprs, fold_aucs)):
    ax_roc.plot(fpr, tpr, color=FOLD_COLORS[i], lw=1.2, ls="--",
                label=f"Fold {i+1} (AUC={a:.3f})")
ax_roc.plot(mean_fpr, mean_tpr, color="navy", lw=2,
            label=f"Mean (AUC={mean_auc:.3f}±{std_auc:.3f})")
ax_roc.plot([0,1],[0,1],"k--",lw=1,alpha=0.5)
ax_roc.set_xlabel("FPR"); ax_roc.set_ylabel("TPR")
ax_roc.set_title("ROC — Fine-Tuned MLP (CODA From SEA and SI)"); ax_roc.legend(fontsize=9)
ax_roc.grid(alpha=0.3)

# RIGHT: Confusion matrices
gs_cm = gridspec.GridSpecFromSubplotSpec(n_folds, 1, subplot_spec=gs[1], hspace=0.55)
for i, (y_true, probs) in enumerate(zip(fold_y_tests, fold_probs)):
    fpr, tpr, ths = roc_curve(y_true, probs)
    thresh = float(ths[np.argmax(tpr - fpr)])
    preds = (probs >= thresh).astype(int)
    cm = confusion_matrix(y_true, preds)
    ax = fig.add_subplot(gs_cm[i])
    ax.imshow(cm, cmap=plt.cm.Blues, vmin=0)
    ax.set_title(f"Fold {i+1} (thr={thresh:.3f})", fontsize=8)
    ax.set_xticks([0,1]); ax.set_xticklabels(["Healthy","TB"], fontsize=7)
    ax.set_yticks([0,1]); ax.set_yticklabels(["Healthy","TB"], fontsize=7, rotation=90, va="center")
    mid = cm.max() / 2
    for r in range(2):
        for c in range(2):
            ax.text(c, r, str(cm[r, c]), ha="center", va="center", fontsize=9,
                    color="white" if cm[r, c] > mid else "black")

plt.suptitle("Fine-Tuned Model Evaluation — CODA From SEA and SI (Per-Fold Test)", fontsize=14, y=1.01)
plt.show()
